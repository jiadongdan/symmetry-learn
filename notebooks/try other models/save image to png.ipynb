# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
dp = r'D:\Dropbox\data\Xiaoxu\bilayer_MoSe2_2H3R'
filename = os.path.join(dp,  'Check 3R phase intensity only-0107.dm3')

# %%
from mtflearn.io import load_image

# %%
img = load_image(filename)

# %%
fig = plt.figure(figsize=(7.2, 7.2))
ax = fig.add_axes([0, 0, 1, 1])
ax.imshow(img)
ax.axis('off')
# Out:
# (np.float64(-0.5), np.float64(383.5), np.float64(383.5), np.float64(-0.5))

# %%
fig.savefig("bilayer MoSe2.png", dpi=300, transparent=False)
